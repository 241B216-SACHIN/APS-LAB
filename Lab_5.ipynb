# %% [markdown]
# <a href="https://colab.research.google.com/github/241B216-SACHIN/APS-LAB/blob/main/Lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2. Divide and Conquer (Sorting)

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# Write a python program to perform **selection sort**.
# - ** -Algorithm
# * Step 1: Read the number of elements for the list from the user.
# * Step 2: Using for loop insert the elements in the list.
# * Step 3: Initialize the minimum element as min=numbers[i].
# * Step 4: Using the swap method the elements are sorted accordingly.
# * Step 5: Print the sorted list.

# %% [markdown]
# ### Selection Sort Program with User Input and Performance Plot

# %% [markdown]
# ### Plotting Running Time for Selection Sort

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
import random
import timeit
import copy

def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr
num_elements = int(input("Enter the number of elements for the list: "))
user_list = []
print("Enter the elements one by one:")
for i in range(num_elements):
    element = int(input(f"Element {i+1}: "))
    user_list.append(element)

print(f"Original list: {user_list}")
sorted_list = selection_sort(user_list.copy())
print(f"Sorted list using Selection Sort: {sorted_list}")
n_values = [100, 500, 1000, 2000, 5000]
times_selection_sort = []

for n in n_values:
    test_list = [random.randint(0, 10000) for _ in range(n)]
    start_time = time.time()
    selection_sort(copy.deepcopy(test_list))
    end_time = time.time()
    times_selection_sort.append((end_time - start_time) * 1000)
plt.figure(figsize=(10, 6))
plt.plot(n_values, times_selection_sort, marker='o', linestyle='-', color='blue')
plt.title('Selection Sort Running Time vs. Input Size (n)')
plt.xlabel('Number of Elements (n)')
plt.ylabel('Time (ms)')
plt.grid(True)
plt.xticks(n_values)
plt.show()
# Out:
# Enter the number of elements for the list: 5
# Enter the elements one by one:
# Element 1: 2
# Element 2: 5
# Element 3: 6
# Element 4: 4
# Element 5: 9
# Original list: [2, 5, 6, 4, 9]
# Sorted list using Selection Sort: [2, 4, 5, 6, 9]

# %% [markdown]
# In computer science, **merge sort** (also commonly spelled mergesort) is an efficient, general-purpose, comparison-based sorting algorithm. Most implementations produce a stable sort, which means that the order of equal elements is the same in the input and output. Merge sort is a divide and conquer algorithm that was invented by John von Neumann in 1945.
# Write a Python program to sort the elements using **merge sort** and plot a graph to the time taken versus n
# - Algorithm(Merge Sort is a divide and conquer algorithm. It divides	input array in two halve.s, calls itself for the two halves and then merges two sorted halves.)
# 1.	Divide the unsorted array into n partitions, each	partition contains 1 element.
# 2.	Repeatedly merge partitioned units to produce	new sublists until there is only l sublist remaining. This will be the sorted	.
# 3.	Compare the first element of the sublist with the first element of the sublist to its right.
# 4.	Merge the two sublists by	paring each element of the sublist and placing the smaller element into the	new sublist.
# 5.	Repeat step 3 and 4 untill	all sublists are merged into a single sorted sublist.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
import random
import timeit
import copy1

def merge_sort(arr):
  if len(arr) > 1:
    mid = len(arr) // 2
    left_half = arr[:mid]
    right_half = arr[mid:]

    merge_sort(left_half)
    merge_sort(right_half)

    i = j = k = 0
    while i < len(left_half) and j < len(right_half):
      if left_half[i] < right_half[j]:
        arr[k] = left_half[i]
        i += 1
      else:
        arr[k] = right_half[j]
        j += 1
      k += 1

    while i < len(left_half):
      arr[k] = left_half[i]
      i += 1
      k += 1

    while j < len(right_half):
      arr[k] = right_half[j]
      j += 1
      k += 1
  return arr
num_elements = int(input("Enter the number of elements for the list: "))
user_list = []
print("Enter the elements one by one:")
for i in range(num_elements):
  element = int(input(f"Element {i+1}: "))
  user_list.append(element)
print(f"Original list: {user_list}")
sorted_list = merge_sort(user_list.copy())
print(f"Sorted list using Merge Sort: {sorted_list}")
n_values = [100, 500, 1000, 2000, 5000]
times_merge_sort = []
for n in n_values:
    test_list = [random.randint(0, 10000) for _ in range(n)]
    start_time = time.time()
    merge_sort(copy.deepcopy(test_list))
    end_time = time.time()
    times_merge_sort.append((end_time - start_time) * 1000)
plt.figure(figsize=(10, 6))
plt.plot(n_values, times_merge_sort, marker='o', linestyle='-', color='blue')
plt.title('Merge Sort Running Time vs. Input Size (n)')
plt.xlabel('Number of Elements (n)')
plt.ylabel('Time (ms)')
plt.grid(True)
plt.xticks(n_values)
plt.show()
# Out:
# Enter the number of elements for the list: 5
# Enter the elements one by one:
# Element 1: 34
# Element 2: 124
# Element 3: 34
# Element 4: 56
# Element 5: 442
# Original list: [34, 124, 34, 56, 442]
# Sorted list using Merge Sort: [34, 34, 56, 124, 442]

# %% [markdown]
# **Quicksort** (sometimes called partition-exchange sort) is an efficient sorting algorithm. Developed by British computer scientist Tony Hoare in 1959 and published in 1961, it is still a commonly used algorithm for sorting.
#
# Quicksort is a divide-and-conquer algorithm. It works by selecting a 'pivot' element from the array and partitioning the other elements into two sub-arrays, according to whether they are less than or greater than the pivot. The sub-arrays are then sorted recursively. This can be done in-place, requiring small additional amounts of memory to perform the sorting.
# Write a Python program to sort the elements using quick sort and plot a graph to the time taken versus n.
# - Algorithm
# 1.	Select a pivot element from the array.
# 2.	Partition the array into two sub-arrays. The elements in the first sub-array are less than the pivot element, while the elements in the second sub-array are greater than the pivot element.
# 3.	Recursively sort the sub-arrays created in Step 2.
# 4.	Join the sub-arrays and the pivot element together to	the sorted array.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import matplotlib.pyplot as plt
import numpy as np
import random
import copy

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)
num_elements = int(input("Enter the number of elements for the list: "))
user_list = []
print("Enter the elements one by one:")
for i in range(num_elements):
  element = int(input(f"Element {i+1}: "))
  user_list.append(element)
print(f"Original list: {user_list}")
sorted_list = quick_sort(user_list.copy())
print(f"Sorted list using Quick Sort: {sorted_list}")
n_values = [100, 500, 1000, 2000, 5000]
times_quick_sort = []
for n in n_values:
    test_list = [random.randint(0, 10000) for _ in range(n)]
    start_time = time.time()
    quick_sort(copy.deepcopy(test_list))
    end_time = time.time()
    times_quick_sort.append((end_time - start_time) * 1000)
plt.figure(figsize=(10, 6))
plt.plot(n_values, times_quick_sort, marker='o', linestyle='-', color='blue')
plt.title('Quick Sort Running Time vs. Input Size (n)')
plt.xlabel('Number of Elements (n)')
plt.ylabel('Time (ms)')
plt.grid(True)
plt.xticks(n_values)
plt.show()
# Out:
# Enter the number of elements for the list: 5
# Enter the elements one by one:
# Element 1: 546
# Element 2: 32
# Element 3: 77
# Element 4: 90
# Element 5: 23
# Original list: [546, 32, 77, 90, 23]
# Sorted list using Quick Sort: [23, 32, 77, 90, 546]

# %% [markdown]
# ### Experiment: compare sorting algorithms

# %%
# Experiment variables
n_list = [1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000]
n_max = n_list[len(n_list) -1]

# %%
# Creating a random value (uniform)
ms = datetime.now().microsecond / 1000
random.seed(ms)

numbers = []
for i in range(n_max):
    numbers.append(int(random.random() * 1000))

# %%
import timeit
import copy
import random

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

def merge_sort(arr):
  if len(arr) > 1:
    mid = len(arr) // 2
    left_half = arr[:mid]
    right_half = arr[mid:]

    merge_sort(left_half)
    merge_sort(right_half)

    i = j = k = 0
    while i < len(left_half) and j < len(right_half):
      if left_half[i] < right_half[j]:
        arr[k] = left_half[i]
        i += 1
      else:
        arr[k] = right_half[j]
        j += 1
      k += 1

    while i < len(left_half):
      arr[k] = left_half[i]
      i += 1
      k += 1

    while j < len(right_half):
      arr[k] = right_half[j]
      j += 1
      k += 1
  return arr

def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr

a_time = []
b_time = []
c_time = []

for l in n_list:
    a = copy.deepcopy(numbers[0:l])
    b = copy.deepcopy(numbers[0:l])
    c = copy.deepcopy(numbers[0:l])

    start_time = timeit.default_timer()
    quick_sort(a)
    a_time.append((timeit.default_timer() - start_time) * 1000)

    start_time = timeit.default_timer()
    merge_sort(b)
    b_time.append((timeit.default_timer() - start_time) * 1000)

    start_time = timeit.default_timer()
    selection_sort(c)
    c_time.append((timeit.default_timer() - start_time) * 1000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1483027647.py in <cell line: 0>()
#      70
#      71     start_time = timeit.default_timer()
# ---> 72     selection_sort(c)
#      73     c_time.append((timeit.default_timer() - start_time) * 1000)
#
# /tmp/ipython-input-1483027647.py in selection_sort(arr)
#      47         min_idx = i
#      48         for j in range(i + 1, n):
# ---> 49             if arr[j] < arr[min_idx]:
#      50                 min_idx = j
#      51         arr[i], arr[min_idx] = arr[min_idx], arr[i]
#
# KeyboardInterrupt:

# %%
# Plotting results
plt.figure(figsize=(10, 5))
plt.plot(a_time, linewidth = 1, marker="o")
plt.plot(b_time, linewidth = 1, marker="o")
plt.plot(c_time, linewidth = 1, marker="o")
plt.xticks(np.arange(len(n_list)), n_list)
plt.title("Compare Sorting Algorithms", fontsize = 14)
plt.ylabel('Time (ms)')
plt.xlabel('n')
plt.legend(("Quicksort", "Mergesort", "Selection sort"), loc = "best")
plt.show()
